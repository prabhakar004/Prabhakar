# %%
import pyspark 
from pyspark.sql.types import * 
from pyspark.sql.functions import * 
from datetime import datetime
from pyspark.sql import SparkSession 
from pyspark.sql.functions import explode
from pyspark.sql.functions import col

# %%
access_key='AKIA2JHMCXOO7VZQSUVZ'
secret_key='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'
aws_region = 'ap-south-1'
sc._jsc.hadoopConfiguration().set('fs.s3a.access.key', access_key)
sc._jsc.hadoopConfiguration().set('fs.s3a.secret.key', secret_key)
sc._jsc.hadoopConfiguration().set('fs.s3a.endpoint', 's3.' + aws_region + '.amazonaws.com')
df = spark.read.format('csv').option('header', 'true').load('s3://surendrabucket4/category.csv')

# %%
#Validation-notempty 
df = df.filter(col('_c0').isNotNull()).limit(100)
df = df.filter(col('catid').isNotNull()).limit(100)

#Validation-custom  
if df.filter(~df['catgroup'].rlike('@')).count() < 0: 
      raise ValueError('Custom validation failed. Stopping processing.') 
 
else:
    df = df.withColumn('_c0', df['_c0'].cast('string'))
    df = df.withColumn('catid', df['catid'].cast('string'))
    df = df.withColumn('catgroup', df['catgroup'].cast('string'))
    df = df.withColumn('catname', df['catname'].cast('string'))
    df = df.withColumn('catdesc', df['catdesc'].cast('integer'))
    df = df.withColumn('catdesc', expr('_c0 + catid'))

# %%
df.write.format('csv').save('s3a://surendrabucket3/Dataopss/')
